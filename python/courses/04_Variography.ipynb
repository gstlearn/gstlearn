# %%
import gstlearn as gl
import gstlearn.plot as gp
import os
import requests

# %%
url = 'http://rgeostats.free.fr/doc/Files/Scotland_Temperatures.csv'
r = requests.get(url, allow_redirects=True)
filepath = 'Scotland_Temperatures.csv'
open(filepath, 'wb').write(r.content)
# Out:
# 4287

# %%
csvf = gl.CSVformat()
csvf.setCharDec('.')
mydb = gl.Db.createFromCSV(filepath, verbose = False, csv = csvf) # URL ?
type(mydb)
mydb
# Out:
# Data Base Characteristics
# =========================
#
# Data Base Summary
# -----------------
# File is organized as a set of isolated points
# Space dimension              = 0
# Number of Columns            = 5
# Maximum Number of UIDs       = 5
# Total number of samples      = 236
#
# Variables
# ---------
# Column = 0 - Name = rank - Locator = NA
# Column = 1 - Name = Longitude - Locator = NA
# Column = 2 - Name = Latitude - Locator = NA
# Column = 3 - Name = Elevation - Locator = NA
# Column = 4 - Name = January_temp - Locator = NA

# %%
#plot(cloud.calc(dat),asp=0,title="")
#varioexp = vario.calc(dat,lag=10,nlag=40)
#class(varioexp)
#class?vario
#varioexp
#plot(varioexp)

# Définition des paramètres de variogramme
myVarioParamOmni = gl.VarioParam()
mydir = gl.DirParam(2,40,10) # TODO : Supprimer ndim (2) dans le futur
myVarioParamOmni.addDirs(mydir)
myVarioParamOmni.display() # TODO : Lag value is missing, Why Grid Ddirection ?
# Out:
# Number of direction(s)      = 1
# Space dimension             = 2
#
# Direction #1
# ------------
# Number of lags              = 40
# Grid Direction coefficients =          1         0

# %%
# Fonction "old school" pour le "Variogram Cloud"
# TODO : Amélioration du message d'erreur (si pas de locator X)
dbcloud = gl.db_variogram_cloud(mydb, myVarioParamOmni)

# %%
mydb.setLocators(["Long*", "Lat*"],gl.ELoc.X)
mydb.setLocator("January_temp",gl.ELoc.Z)
mydb
# Out:
# Data Base Characteristics
# =========================
#
# Data Base Summary
# -----------------
# File is organized as a set of isolated points
# Space dimension              = 2
# Number of Columns            = 5
# Maximum Number of UIDs       = 5
# Total number of samples      = 236
#
# Variables
# ---------
# Column = 0 - Name = rank - Locator = NA
# Column = 1 - Name = Longitude - Locator = x1
# Column = 2 - Name = Latitude - Locator = x2
# Column = 3 - Name = Elevation - Locator = NA
# Column = 4 - Name = January_temp - Locator = z1

# %%
help(gl.db_variogram_cloud)
# Out:
# Help on function db_variogram_cloud in module gstlearn:
#
# db_variogram_cloud(*args, **kwargs) -> 'DbGrid *'

# %%
#gp.grid(dbcloud,"Cloud*",title="Variogram Cloud")
dbcloud = gl.db_variogram_cloud(mydb, myVarioParamOmni)
dbcloud

# TODO : Locatoriser Z la variable Cloud.January_temp
#
# Out:
# Data Base Grid Characteristics
# ==============================
#
# Data Base Summary
# -----------------
# File is organized as a regular grid
# Space dimension              = 2
# Number of Columns            = 4
# Maximum Number of UIDs       = 4
# Total number of samples      = 10000
#
# Grid characteristics:
# ---------------------
# Origin :      0.000     0.000
# Mesh   :      7.789     0.106
# Number :        100       100
#
# Variables
# ---------
# Column = 0 - Name = rank - Locator = NA
# Column = 1 - Name = x1 - Locator = x1
# Column = 2 - Name = x2 - Locator = x2
# Column = 3 - Name = Cloud.January_temp - Locator = NA

# %%
dbfmt = gl.DbStringFormat()
dbfmt.setParams(gl.FLAG_VARS | gl.FLAG_STATS)
dbcloud.display(dbfmt)
# Out:
# Data Base Grid Characteristics
# ==============================
#
# Data Base Statistics
# --------------------
# 1 - Name rank - Locator NA
#  Nb of data          =      10000
#  Nb of active values =      10000
#  Minimum value       =      1.000
#  Maximum value       =  10000.000
#  Mean value          =   5000.500
#  Standard Deviation  =   2886.751
#  Variance            = 8333333.250
# 2 - Name x1 - Locator x1
#  Nb of data          =      10000
#  Nb of active values =      10000
#  Minimum value       =      0.000
#  Maximum value       =    771.100
#  Mean value          =    385.550
#  Standard Deviation  =    224.835
#  Variance            =  50550.653
# 3 - Name x2 - Locator x2
#  Nb of data          =      10000
#  Nb of active values =      10000
#  Minimum value       =      0.000
#  Maximum value       =     10.474
#  Mean value          =      5.237
#  Standard Deviation  =      3.054
#  Variance            =      9.327
# 4 - Name Cloud.January_temp - Locator NA
#  Nb of data          =      10000
#  Nb of active values =       1608
#  Minimum value       =      1.000
#  Maximum value       =     99.000
#  Mean value          =      7.042
#  Standard Deviation  =     10.414
#  Variance            =    108.447
#
# Variables
# ---------
# Column = 0 - Name = rank - Locator = NA
# Column = 1 - Name = x1 - Locator = x1
# Column = 2 - Name = x2 - Locator = x2
# Column = 3 - Name = Cloud.January_temp - Locator = NA

# %%
gp.grid(dbcloud,"Cloud*",title="Variogram Cloud")
# TODO :
# - Proposer un bon réglage des facteurs d'échelle par défaut dans gp.grid
# Out:
# <AxesSubplot:title={'center':'Variogram Cloud'}>

# %%
# Possible with points display
gp.point(dbcloud,"Cloud*",title="Variogram Cloud")
# Out:
# <AxesSubplot:title={'center':'Variogram Cloud'}>

# %%
# Compute the experimental variogram
myVarioOmni = gl.Vario(myVarioParamOmni,mydb)
err = myVarioOmni.compute("vg") # TODO : Use the ENUM 
myVarioOmni.display()

# TODO : 
# - Créer un ou plusieurs raccourci createFrom???? avec des paramètres directement en arguments
# Out:
# Variogram characteristics
# =========================
# Number of variable(s)       = 1
# Number of direction(s)      = 1
# Space dimension             = 2
# Variance-Covariance Matrix     1.020
#
# Direction #1
# ------------
# Number of lags              = 40
# Direction coefficients      =      1.000     0.000
# Direction angles (degrees)  =      0.000     0.000
# Tolerance on direction      =     90.000 (degrees)
# Calculation lag             =     10.000
# Tolerance on distance       =     50.000 (Percent of the lag value)
#
# For variable 1
#       Rank    Npairs  Distance     Value
#          0    19.000     3.118     0.042
#          1    89.000    10.690     0.172
#          2   168.000    20.346     0.280
#          3   244.000    30.323     0.456
#          4   316.000    40.429     0.459
#          5   385.000    50.162     0.660
#          6   399.000    60.296     0.729
#          7   463.000    70.062     0.874
#          8   450.000    79.807     0.800
#          9   473.000    90.115     0.977
#         10   549.000   100.141     0.879
#         11   484.000   109.866     0.970
#         12   491.000   119.865     1.082
#         13   458.000   130.001     1.074
#         14   474.000   139.888     0.983
#         15   472.000   149.918     1.086
#         16   390.000   159.896     1.218
#         17   410.000   169.913     1.303
#         18   385.000   179.840     1.212
#         19   425.000   189.849     1.079
#         20   354.000   200.117     1.168
#         21   341.000   209.881     1.229
#         22   325.000   219.710     1.497
#         23   296.000   229.902     1.597
#         24   277.000   239.927     1.419
#         25   236.000   250.111     1.353
#         26   201.000   259.921     1.449
#         27   177.000   270.161     1.335
#         28   166.000   279.560     1.245
#         29   177.000   289.873     1.089
#         30   148.000   299.866     0.992
#         31   116.000   310.335     1.130
#         32    95.000   319.854     1.161
#         33    92.000   329.857     1.330
#         34    64.000   339.936     1.151
#         35    57.000   350.172     1.551
#         36    61.000   359.473     1.395
#         37    51.000   369.274     1.350
#         38    33.000   380.087     0.847
#         39    31.000   389.553     1.014

# %%
# TODO : Fix direction display
myVarioParam2 = gl.VarioParam()
myVarioParam2.addMultiDirs(gl.generateMultipleDirs(2, 4, 10, 1))
myVarioParam2
# Out:
# Number of direction(s)      = 4
# Space dimension             = 2
#
# Direction #1
# ------------
# Number of lags              = 10
# Grid Direction coefficients =          1         0
#
# Direction #2
# ------------
# Number of lags              = 10
# Grid Direction coefficients =          1         0
#
# Direction #3
# ------------
# Number of lags              = 10
# Grid Direction coefficients =          1         0
#
# Direction #4
# ------------
# Number of lags              = 10
# Grid Direction coefficients =          1         0

# %%
help(gl.Vario)
# Out:
# Help on class Vario in module gstlearn:
#
# class Vario(AStringable, ASerializable, IClonable)
#  |  Vario(*args)
#  |
#  |  Method resolution order:
#  |      Vario
#  |      AStringable
#  |      ASerializable
#  |      IClonable
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self) -> 'std::string'
#  |      Return repr(self).
#  |
#  |  addDirs(self, dirparam: 'DirParam') -> 'void'
#  |
#  |  attachDb(self, *args, **kwargs) -> 'int'
#  |
#  |  clone(self) -> 'IClonable *'
#  |
#  |  compute(self, *args, **kwargs) -> 'int'
#  |
#  |  computeIndic(self, *args, **kwargs) -> 'int'
#  |
#  |  dumpToNF(self, neutralFilename: 'String const &', verbose: 'bool' = False) -> 'int'
#  |
#  |  fill(self, idir: 'int', sw: 'VectorDouble', gg: 'VectorDouble', hh: 'VectorDouble') -> 'int'
#  |
#  |  getAllGg(self, idir: 'int') -> 'VectorDouble const &'
#  |
#  |  getAllHh(self, idir: 'int') -> 'VectorDouble const &'
#  |
#  |  getAllSw(self, idir: 'int') -> 'VectorDouble const &'
#  |
#  |  getAllUtilize(self, idir: 'int') -> 'VectorDouble const &'
#  |
#  |  getCalculName(self) -> 'String const &'
#  |
#  |  getCalculType(self) -> 'ECalcVario'
#  |
#  |  getCenter(self, ivar: 'int' = 0, jvar: 'int' = 0, idir: 'int' = 0) -> 'int'
#  |
#  |  getCodir(self, *args) -> 'double'
#  |
#  |  getDPas(self, idir: 'int') -> 'double'
#  |
#  |  getDateNumber(self) -> 'int'
#  |
#  |  getDates(self, *args) -> 'double'
#  |
#  |  getDimensionNumber(self, *args) -> 'int'
#  |
#  |  getDirAddress(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int', flag_abs: 'bool' = False, sens: 'int' = 0) -> 'int'
#  |
#  |  getDirParam(self, idir: 'int') -> 'DirParam const &'
#  |
#  |  getDirSize(self, idir: 'int') -> 'int'
#  |
#  |  getDirectionNumber(self) -> 'int'
#  |
#  |  getFlagAsym(self) -> 'bool'
#  |
#  |  getGRange(self, ivar: 'int' = -1, jvar: 'int' = -1, idir: 'int' = -1, flagSill: 'bool' = False) -> 'VectorDouble'
#  |
#  |  getGg(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int', asCov: 'bool' = False, flagNormalized: 'bool' = False) -> 'double'
#  |
#  |  getGgByIndex(self, idir: 'int', i: 'int') -> 'double'
#  |
#  |  getGgVec(self, idir: 'int', ivar: 'int', jvar: 'int', asCov: 'bool' = False, flagNormalized: 'bool' = False) -> 'VectorDouble'
#  |
#  |  getGmax(self, ivar: 'int' = -1, jvar: 'int' = -1, idir: 'int' = -1, flagAbs: 'bool' = False, flagSill: 'bool' = False) -> 'double'
#  |
#  |  getGrincr(self, idir: 'int', idim: 'int') -> 'double'
#  |
#  |  getHRange(self, ivar: 'int' = -1, jvar: 'int' = -1, idir: 'int' = -1) -> 'VectorDouble'
#  |
#  |  getHh(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int') -> 'double'
#  |
#  |  getHhByIndex(self, idir: 'int', i: 'int') -> 'double'
#  |
#  |  getHhVec(self, idir: 'int', ivar: 'int', jvar: 'int') -> 'VectorDouble'
#  |
#  |  getHmax(self, ivar: 'int' = -1, jvar: 'int' = -1, idir: 'int' = -1) -> 'double'
#  |
#  |  getIdate(self, idir: 'int') -> 'int'
#  |
#  |  getLagNumber(self, idir: 'int') -> 'int'
#  |
#  |  getLagTotalNumber(self, idir: 'int') -> 'int'
#  |
#  |  getMaximumDistance(self, idir: 'int') -> 'double'
#  |
#  |  getMean(self, ivar: 'int') -> 'double'
#  |
#  |  getMeans(self) -> 'VectorDouble const &'
#  |
#  |  getScale(self) -> 'double'
#  |
#  |  getSw(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int') -> 'double'
#  |
#  |  getSwByIndex(self, idir: 'int', i: 'int') -> 'double'
#  |
#  |  getSwVec(self, idir: 'int', ivar: 'int', jvar: 'int') -> 'VectorDouble'
#  |
#  |  getUtilize(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int') -> 'double'
#  |
#  |  getUtilizeByIndex(self, idir: 'int', i: 'int') -> 'double'
#  |
#  |  getUtilizeVec(self, idir: 'int', ivar: 'int', jvar: 'int') -> 'VectorDouble'
#  |
#  |  getVar(self, ivar: 'int', jvar: 'int') -> 'double'
#  |
#  |  getVarAddress(self, ivar: 'int', jvar: 'int') -> 'int'
#  |
#  |  getVarIndex(self, ijvar: 'int') -> 'double'
#  |
#  |  getVariableNumber(self) -> 'int'
#  |
#  |  getVarioParam(self) -> 'VarioParam const &'
#  |
#  |  getVars(self) -> 'VectorDouble const &'
#  |
#  |  hasDate(self) -> 'bool'
#  |
#  |  internalDirectionResize(self, ndir: 'int' = 0, flagDirs: 'bool' = True) -> 'void'
#  |
#  |  internalVariableResize(self) -> 'int'
#  |
#  |  patchCenter(self, idir: 'int', nech: 'int', rho: 'double') -> 'void'
#  |
#  |  reduce(self, varcols: 'VectorInt', dircols: 'VectorInt', asSymmetric: 'bool' = False) -> 'void'
#  |
#  |  setCalculName(self, calcul_name: 'String const') -> 'void'
#  |
#  |  setGg(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int', gg: 'double') -> 'void'
#  |
#  |  setGgByIndex(self, idir: 'int', i: 'int', gg: 'double') -> 'void'
#  |
#  |  setHh(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int', hh: 'double') -> 'void'
#  |
#  |  setHhByIndex(self, idir: 'int', i: 'int', hh: 'double') -> 'void'
#  |
#  |  setMean(self, ivar: 'int', mean: 'double') -> 'void'
#  |
#  |  setMeans(self, means: 'VectorDouble') -> 'void'
#  |
#  |  setNVar(self, nvar: 'int') -> 'void'
#  |
#  |  setScale(self, scale: 'double') -> 'void'
#  |
#  |  setSw(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int', sw: 'double') -> 'void'
#  |
#  |  setSwByIndex(self, idir: 'int', i: 'int', sw: 'double') -> 'void'
#  |
#  |  setUtilize(self, idir: 'int', ivar: 'int', jvar: 'int', ipas: 'int', utilize: 'double') -> 'void'
#  |
#  |  setUtilizeByIndex(self, idir: 'int', i: 'int', utilize: 'double') -> 'void'
#  |
#  |  setVar(self, ivar: 'int', jvar: 'int', value: 'double') -> 'void'
#  |
#  |  setVarIndex(self, ijvar: 'int', value: 'double') -> 'void'
#  |
#  |  setVars(self, vars: 'VectorDouble') -> 'void'
#  |
#  |  toString(self, strfmt: 'AStringFormat' = None) -> 'String'
#  |
#  |  updateGgByIndex(self, idir: 'int', i: 'int', gg: 'double') -> 'void'
#  |
#  |  updateHhByIndex(self, idir: 'int', i: 'int', hh: 'double') -> 'void'
#  |
#  |  updateSwByIndex(self, idir: 'int', i: 'int', sw: 'double') -> 'void'
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __swig_destroy__ = delete_Vario(...)
#  |
#  |  create(*args, **kwargs) -> 'Vario *'
#  |
#  |  createFromNF(neutralFilename: 'String const &', verbose: 'bool' = False) -> 'Vario *'
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  thisown
#  |      The membership flag
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from AStringable:
#  |
#  |  display(self, *args) -> 'void'
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from AStringable:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from ASerializable:
#  |
#  |  buildFileName(filename: 'String const &', ensureDirExist: 'bool' = False) -> 'String'
#  |
#  |  createDirectory(dir: 'String const &') -> 'bool'
#  |
#  |  getContainerName() -> 'String const &'
#  |
#  |  getDirectory(path: 'String const &') -> 'String'
#  |
#  |  getExecDirectory() -> 'String'
#  |
#  |  getFileIdentity(filename: 'String const &') -> 'String'
#  |
#  |  getHomeDirectory(*args, **kwargs) -> 'String'
#  |
#  |  getPrefixName() -> 'String const &'
#  |
#  |  getTestData(subdir: 'String const &', filename: 'String const &') -> 'String'
#  |
#  |  setContainerName(*args, **kwargs) -> 'void'
#  |
#  |  setPrefixName(prefixName: 'String const &') -> 'void'
#  |
#  |  unsetContainerName() -> 'void'
#  |
#  |  unsetPrefixName() -> 'void'

# %%
# TODO :
# - Ajouter title et autre kwargs (légende, couleurs, etc...)
# - Attention au nommage des arguments (prendre des noms différents de matplotlib pour les arguments propres à chaque fonction)
# - Attention au passage des kwargs aux fonctions de matplotlib (et dont on aurait également besoin dans la fonction)
# - Add number of pairs (and so on) (si on a le temps)
axs = gp.plot(myVarioOmni)

# TODO : Access by operator [] or column names ? (si on a le temps)
# Here : 1 is the second direction !! etc...
#myVarioOmni[1]$nlag
#myVarioOmni[1]$gg
# Example : Number of pairs for the first direction, and the fifth lag (si on a le temps)
#myVarioOmni[0].Npairs[4] # TODO (better)
myVarioOmni.getSwVec(0,0,0)[4] # Bof
# Out:
# 316.0

# %%
# Should be also possible : => Done
# TODO :
# - Ajouter title et autre kwargs (légende, couleurs, etc...)
myVarioOmni.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-975ffae0b07c> in <module>
# ----> 1 myVarioOmni.plot()
#
# AttributeError: 'Vario' object has no attribute 'plot'

# %%
# Create empty model customized with the space dimension from the Db
mymodel = gl.Model.createFromDb(mydb)
err = mymodel.fit(myVarioOmni,[gl.ECov.EXPONENTIAL,gl.ECov.SPHERICAL])

# %%
ax = gp.model(mymodel)
#gp.plot(mymodel) # TODO : error in generic function => Done

# %%
ax = gp.varmod(myVarioOmni,mymodel)
